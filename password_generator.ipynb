# %% [markdown]
# <a href="https://colab.research.google.com/github/maeyda-masroor/04_assignment_python/blob/days/password_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
print("password generator")
chars = 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!@#$%&*'
number = input("Amout of password")
number1=int(number)
length = input("enter legth")
length1 = int(length)
print("paasswors")

for pwd in range(number1):
  password = ''
  for c in range(length1):
    password+=random.choice(chars)
  print(password)
# Out:
# password generator
# Amout of password8
# enter legth4
# paasswors
# MLSI
# CszI
# az%p
# auiR
# #N@&
# wNrC
# vaNU
# PrKa
