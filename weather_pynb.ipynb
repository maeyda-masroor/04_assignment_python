# %% [markdown]
# <a href="https://colab.research.google.com/github/maeyda-masroor/04_assignment_python/blob/days/weather_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from pprint import pprint
API_KEY="544f179e3d863287ea23403438247324"
city_name = input("Enter city name").strip()
base_url = 'http://openweathermap.org/data/2.5/weather?=appid='+API_KEY+"&q="+city_name
response  = requests.get(base_url)
print(response)
# Out:
# Enter city nameKarachi
# <Response [401]>
