# %% [markdown]
# <a href="https://colab.research.google.com/github/maeyda-masroor/04_assignment_python/blob/days/Web_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install beautifulsoup4 requests lxml html5lib

# %%
import requests
from bs4 import BeautifulSoup as bs
github_user = input("Enter gihub user")
url = "https://github.com/"+github_user
r = requests.get(url)
soup = bs(r.content,'html.parser')
profile_image = soup.find("img",{"alt":"Avatar"})
if profile_image is not None:
    profile_image = profile_image.get("src")
print(profile_image)
# Out:
# Enter gihub usermaeyda-masroor
# None
